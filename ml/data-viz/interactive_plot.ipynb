# %%
# Create an interactive plot with simple linear model

import pandas as pd

df = pd.read_csv("resources/gdp-vs-happiness.csv")

df.head()
# Out:
#         Entity Code  Year  GDP per capita (constant 2011 international $)  \
# 0  Afghanistan  AFG  1800                                             NaN
# 1  Afghanistan  AFG  1801                                             NaN
# 2  Afghanistan  AFG  1802                                             NaN
# 3  Afghanistan  AFG  1803                                             NaN
# 4  Afghanistan  AFG  1804                                             NaN
#
#    Life satisfaction (country average; 0-10) (Cantril Ladder (0=worst; 10=best))  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Unnamed: 5
# 0   3280000.0
# 1   3280000.0
# 2   3280000.0
# 3   3280000.0
# 4   3280000.0

# %%
# %config IPCompleter.greedy=True

df[(df['GDP per capita (constant 2011 international $)'].notna()) & \
   (df['Year'] == 2017)]
# Out:
#                     Entity      Code  Year  \
# 217            Afghanistan       AFG  2017
# 559                Albania       ALB  2017
# 779                Algeria       DZA  2017
# 1289                Angola       AGO  2017
# 1579   Antigua and Barbuda       ATG  2017
# ...                    ...       ...   ...
# 46506              Vanuatu       VUT  2017
# 47166              Vietnam       VNM  2017
# 47457                World  OWID_WRL  2017
# 47897               Zambia       ZMB  2017
# 48117             Zimbabwe       ZWE  2017
#
#        GDP per capita (constant 2011 international $)  \
# 217                                       1803.987487
# 559                                      11803.430594
# 779                                      13913.839363
# 1289                                      5819.494971
# 1579                                     21490.942659
# ...                                               ...
# 46506                                     2921.908676
# ...

# %%
from bokeh.plotting import figure, output_file, show

from bokeh.models import CustomJS, Slider
from bokeh.layouts import row, column

df_filtered = \
    df[(df['Year'] == 2017) & \
       (df['GDP per capita (constant 2011 international $)'].notna()) & \
       (df['Life satisfaction (country average; 0-10) (Cantril Ladder (0=worst; 10=best))'].notna())
      ]

output_file('resources/gdp-vs-happiness.html')

p = figure(plot_width=800, plot_height=800)


x = df_filtered['GDP per capita (constant 2011 international $)'].tolist()

y = df_filtered['Life satisfaction (country average; 0-10) (Cantril Ladder (0=worst; 10=best))'].tolist()
